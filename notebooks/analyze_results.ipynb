# %%
import sys
sys.path.append('..')

from analysis import *
import pandas as pd
pd.set_option('precision', 4)
# Out:
# 2022-11-04 13:59:13.240327: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# ### Table_III

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_III()

analyze_table_III(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset      MSL    SMAP      A1      A2      A3      A4     Art    AdEx  \
# pipeline
# ARIMA     0.4421  0.3333  0.7332  0.8074  0.8176  0.6998  0.3529  0.5176
# LSTM-DT   0.5155  0.7075  0.7206  0.9801  0.7442  0.6379  0.4000  0.5128
# LSTM-AE   0.4571  0.7259  0.6391  0.9610  0.5938  0.3678  0.4444  0.6786
# LSTM-VAE  0.4324  0.6056  0.6171  0.9124  0.5977  0.3263  0.4444  0.7018
# TadGAN    0.5843  0.6174  0.5325  0.8421  0.3907  0.2969  0.5714  0.6774
# AER       0.5405  0.7717  0.7723  0.9586  0.8964  0.7222  0.6154  0.6349
#
# dataset      AWS  Traffic  Tweets     UCR  AVG (F1)  SD (F1)
# pipeline
# ARIMA     0.7407   0.5000  0.5672  0.1236    0.5530   0.2068
# LSTM-DT   0.7407   0.6667  0.5797  0.3908    0.6330   0.1589
# LSTM-AE   0.6429   0.5926  0.5357  0.3292    0.5807   0.1651
# LSTM-VAE  0.7586   0.5926  0.5357  0.3540    0.5732   0.1625
# TadGAN    0.7200   0.5806  0.5882  0.1625    0.5470   0.1777
# AER       0.6207   0.6061  0.5846  0.4698    0.6828   0.1449

# %% [markdown]
# ### Table_IV_A

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_IV_A()

analyze_table_IV_A(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset             MSL    SMAP      A1      A2      A3      A4     Art  \
# pipeline
# ARIMA            0.4421  0.3333  0.7332  0.8074  0.8176  0.6998  0.3529
# ARIMA (M)        0.4565  0.3590  0.7519  0.8093  0.8069  0.6899  0.5000
# LSTM-DT          0.5155  0.7075  0.7206  0.9801  0.7442  0.6379  0.4000
# LSTM-DT (M)      0.5208  0.7536  0.7287  0.9875  0.7335  0.6378  0.6000
# LSTM-DT (M, Bi)  0.5049  0.6620  0.7550  0.9494  0.8947  0.7917  0.5455
# LSTM-AE          0.4571  0.7259  0.6391  0.9610  0.5938  0.3678  0.4444
# LSTM-AE (M)      0.4571  0.7717  0.6448  0.9633  0.5938  0.3670  0.4444
# LSTM-VAE         0.4324  0.6056  0.6171  0.9124  0.5977  0.3263  0.4444
# LSTM-VAE (M)     0.4384  0.7049  0.6292  0.9406  0.5946  0.3279  0.4444
# TadGAN           0.5843  0.6174  0.5325  0.8421  0.3907  0.2969  0.5714
# TadGAN (M)       0.5843  0.6301  0.5342  0.8462  0.3950  0.2913  0.6154
#
# dataset            AdEx     AWS  Traffic  Tweets     UCR  AVG (F1)  SD (F1)
# pipeline
# ...

# %% [markdown]
# ### Table_IV_B

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_IV_B()

analyze_table_IV_B(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset        MSL    SMAP      A1      A2      A3      A4     Art    AdEx  \
# pipeline
# AER (PRED)  0.4944  0.6846  0.7047  0.9227  0.8964  0.7222  0.5000  0.5412
# AER (SUM)   0.4878  0.6803  0.7139  0.9359  0.7192  0.5532  0.5000  0.7018
# AER (REC)   0.5000  0.6825  0.7072  0.9850  0.6203  0.4160  0.4444  0.6441
# AER (MULT)  0.5405  0.7717  0.7723  0.9586  0.7525  0.5719  0.6154  0.6349
#
# dataset        AWS  Traffic  Tweets     UCR  AVG (F1)  SD (F1)
# pipeline
# AER (PRED)  0.6875   0.6154  0.5556  0.4613    0.6488   0.1444
# AER (SUM)   0.7333   0.6061  0.5588  0.4277    0.6348   0.1342
# AER (REC)   0.6923   0.5714  0.5185  0.3629    0.5954   0.1604
# AER (MULT)  0.6207   0.6061  0.5846  0.4698    0.6583   0.1271

# %% [markdown]
# ### Figure 3

# %%
make_figure_3()

# %% [markdown]
# ### Figure 4

# %%
make_figure_4()

# %% [markdown]
# ### Figure 6

# %%
make_figure_6()
