# %%
import sys
sys.path.append('..')

from analysis import *
import pandas as pd
pd.set_option('precision', 4)
# Out:
# 2022-10-30 15:26:50.086266: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# ### Table_III

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_III()

analyze_table_III(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset      MSL    SMAP      A1      A2      A3      A4     Art    AdEx  \
# pipeline
# ARIMA     0.4421  0.3333  0.7332  0.8074  0.8176  0.6998  0.3529  0.5176
# LSTM-DT   0.5155  0.7075  0.7206  0.9801  0.7442  0.6379  0.4000  0.5128
# LSTM-AE   0.4571  0.7259  0.6391  0.9610  0.5938  0.3678  0.4444  0.6786
# LSTM-VAE  0.4324  0.6056  0.6171  0.9124  0.5977  0.3263  0.4444  0.7018
# TadGAN    0.5843  0.6174  0.5325  0.8421  0.3907  0.2969  0.5714  0.6774
# AER       0.6111  0.7969  0.7896  0.9586  0.8815  0.7281  0.5000  0.6562
#
# dataset      AWS  Traffic  Tweets     UCR  AVG (F1)  SD (F1)
# pipeline
# ARIMA     0.7407   0.5000  0.5672  0.1236    0.5530   0.2068
# LSTM-DT   0.7407   0.6667  0.5797  0.3908    0.6330   0.1589
# LSTM-AE   0.6429   0.5926  0.5357  0.3292    0.5807   0.1651
# LSTM-VAE  0.7586   0.5926  0.5357  0.3540    0.5732   0.1625
# TadGAN    0.7200   0.5806  0.5882  0.1625    0.5470   0.1777
# AER       0.6207   0.5625  0.5714  0.4852    0.6802   0.1511

# %% [markdown]
# ### Table_IV_A

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_IV_A()

analyze_table_IV_A(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset          MSL    SMAP      A1      A2      A3      A4     Art    AdEx  \
# pipeline
# ARIMA         0.4421  0.3333  0.7332  0.8074  0.8176  0.6998  0.3529  0.5176
# ARIMA (M)     0.4565  0.3590  0.7519  0.8093  0.8069  0.6899  0.5000  0.5176
# LSTM-DT       0.5155  0.7075  0.7206  0.9801  0.7442  0.6379  0.4000  0.5128
# LSTM-DT (M)   0.5208  0.7536  0.7287  0.9875  0.7335  0.6378  0.6000  0.5128
# LSTM-AE       0.4571  0.7259  0.6391  0.9610  0.5938  0.3678  0.4444  0.6786
# LSTM-AE (M)   0.4571  0.7717  0.6448  0.9633  0.5938  0.3670  0.4444  0.6786
# LSTM-VAE      0.4324  0.6056  0.6171  0.9124  0.5977  0.3263  0.4444  0.7018
# LSTM-VAE (M)  0.4384  0.7049  0.6292  0.9406  0.5946  0.3279  0.4444  0.7143
# TadGAN        0.5843  0.6174  0.5325  0.8421  0.3907  0.2969  0.5714  0.6774
# TadGAN (M)    0.5843  0.6301  0.5342  0.8462  0.3950  0.2913  0.6154  0.6774
#
# dataset          AWS  Traffic  Tweets     UCR  AVG (F1)  SD (F1)
# pipeline
# ARIMA         0.7407   0.5000  0.5672  0.1236    0.5530   0.2068
# ARIMA (M)     0.7692   0.5000  0.5758  0.1481    0.5737   0.1933
# LSTM-DT       0.7407   0.6667  0.5797  0.3908    0.6330   0.1589
# LSTM-DT (M)   0.7692   0.6857  0.5882  0.4461    0.6637   0.1398
# LSTM-AE       0.6429   0.5926  0.5357  0.3292    0.5807   0.1651
# LSTM-AE (M)   0.6429   0.6154  0.5357  0.3333    0.5873   0.1693
# LSTM-VAE      0.7586   0.5926  0.5357  0.3540    0.5732   0.1625
# LSTM-VAE (M)  0.7586   0.6154  0.5357  0.3607    0.5887   0.1709
# TadGAN        0.7200   0.5806  0.5882  0.1625    0.5470   0.1777
# TadGAN (M)    0.7200   0.5806  0.5882  0.1642    0.5522   0.1796

# %% [markdown]
# ### Table_IV_B

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_IV_B()

analyze_table_IV_B(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset        MSL    SMAP      A1      A2      A3      A4     Art    AdEx  \
# pipeline
# AER (PRED)  0.5227  0.6944  0.7146  0.9359  0.8815  0.7281  0.8000  0.4946
# AER (SUM)   0.5060  0.7273  0.7193  0.9381  0.7166  0.5367  0.5000  0.7241
# AER (REC)   0.4800  0.6992  0.7086  0.9752  0.6207  0.4200  0.4444  0.6786
# AER (MULT)  0.6111  0.7969  0.7896  0.9586  0.7472  0.5784  0.5000  0.6562
#
# dataset        AWS  Traffic  Tweets     UCR  AVG (F1)  SD (F1)
# pipeline
# AER (PRED)  0.7097   0.7368  0.6000  0.4635    0.6902   0.1413
# AER (SUM)   0.7333   0.5882  0.5373  0.4448    0.6393   0.1366
# AER (REC)   0.6429   0.5714  0.5000  0.3807    0.5935   0.1582
# AER (MULT)  0.6207   0.5625  0.5714  0.4852    0.6565   0.1342
