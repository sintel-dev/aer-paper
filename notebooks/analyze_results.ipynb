# %%
import sys
sys.path.append('..')

from analysis import *
import pandas as pd
pd.set_option('precision', 3)
# Out:
# 2022-11-06 23:31:38.065307: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1

# %% [markdown]
# ### Table_III

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_III()

analyze_table_III(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset     MSL   SMAP     A1     A2     A3     A4    Art   AdEx    AWS  \
# pipeline
# ARIMA     0.442  0.333  0.733  0.807  0.818    0.7  0.353  0.518  0.741
# LSTM-DT   0.515  0.707  0.721   0.98  0.744  0.638    0.4  0.513  0.741
# LSTM-AE   0.457  0.726  0.639  0.961  0.594  0.368  0.444  0.679  0.643
# LSTM-VAE  0.432  0.606  0.617  0.912  0.598  0.326  0.444  0.702  0.759
# TadGAN    0.584  0.617  0.533  0.842  0.391  0.297  0.571  0.677   0.72
# AER       0.541  0.772  0.772  0.959  0.896  0.722  0.615  0.635  0.621
#
# dataset  Traffic Tweets    UCR AVG (F1)   SD (F1)
# pipeline
# ARIMA        0.5  0.567  0.124    0.553      0.21
# LSTM-DT    0.667   0.58  0.391    0.633      0.16
# LSTM-AE    0.593  0.536  0.329    0.581      0.17
# LSTM-VAE   0.593  0.536  0.354    0.573      0.16
# TadGAN     0.581  0.588  0.162    0.547      0.18
# AER        0.606  0.585   0.47    0.683  0.144915

# %% [markdown]
# ### Table_IV_A

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_IV_A()

analyze_table_IV_A(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset            MSL   SMAP     A1     A2     A3     A4    Art   AdEx  \
# pipeline
# ARIMA            0.442  0.333  0.733  0.807  0.818    0.7  0.353  0.518
# ARIMA (M)        0.457  0.359  0.752  0.809  0.807   0.69    0.5  0.518
# LSTM-DT          0.515  0.707  0.721   0.98  0.744  0.638    0.4  0.513
# LSTM-DT (M)      0.521  0.754  0.729  0.987  0.734  0.638    0.6  0.513
# LSTM-DT (M, Bi)  0.505  0.662  0.755  0.949  0.895  0.792  0.545  0.488
# LSTM-AE          0.457  0.726  0.639  0.961  0.594  0.368  0.444  0.679
# LSTM-AE (M)      0.457  0.772  0.645  0.963  0.594  0.367  0.444  0.679
# LSTM-VAE         0.432  0.606  0.617  0.912  0.598  0.326  0.444  0.702
# LSTM-VAE (M)     0.438  0.705  0.629  0.941  0.595  0.328  0.444  0.714
# TadGAN           0.584  0.617  0.533  0.842  0.391  0.297  0.571  0.677
# TadGAN (M)       0.584   0.63  0.534  0.846  0.395  0.291  0.615  0.677
#
# dataset            AWS Traffic Tweets    UCR AVG (F1) SD (F1)
# pipeline
# ARIMA            0.741     0.5  0.567  0.124    0.553    0.21
# ARIMA (M)        0.769     0.5  0.576  0.148    0.574    0.19
# LSTM-DT          0.741   0.667   0.58  0.391    0.633    0.16
# LSTM-DT (M)      0.769   0.686  0.588  0.446    0.664    0.14
# LSTM-DT (M, Bi)  0.786   0.684  0.587  0.432    0.673    0.16
# LSTM-AE          0.643   0.593  0.536  0.329    0.581    0.17
# LSTM-AE (M)      0.643   0.615  0.536  0.333    0.587    0.17
# LSTM-VAE         0.759   0.593  0.536  0.354    0.573    0.16
# LSTM-VAE (M)     0.759   0.615  0.536  0.361    0.589    0.17
# TadGAN            0.72   0.581  0.588  0.162    0.547    0.18
# TadGAN (M)        0.72   0.581  0.588  0.164    0.552    0.18

# %% [markdown]
# ### Table_IV_B

# %%
# if you already run `run_benchmark.ipynb` and the results
# are saved into the results folder
# simply call analyze_table_IV_B()

analyze_table_IV_B(f'{RESULTS_DIRECTORY}/paper-results')
# Out:
# dataset       MSL   SMAP     A1     A2     A3     A4    Art   AdEx    AWS  \
# pipeline
# AER (PRED)  0.494  0.685  0.705  0.923  0.896  0.722    0.5  0.541  0.688
# AER (SUM)   0.488   0.68  0.714  0.936  0.719  0.553    0.5  0.702  0.733
# AER (REC)     0.5  0.683  0.707  0.985   0.62  0.416  0.444  0.644  0.692
# AER (MULT)  0.541  0.772  0.772  0.959  0.752  0.572  0.615  0.635  0.621
#
# dataset    Traffic Tweets    UCR AVG (F1) SD (F1)
# pipeline
# AER (PRED)   0.615  0.556  0.461    0.649    0.14
# AER (SUM)    0.606  0.559  0.428    0.635    0.13
# AER (REC)    0.571  0.519  0.363    0.595    0.16
# AER (MULT)   0.606  0.585   0.47    0.658    0.13

# %% [markdown]
# ### Figure 3

# %%
make_figure_3()

# %% [markdown]
# ### Figure 4

# %%
make_figure_4()

# %% [markdown]
# ### Figure 6

# %%
make_figure_6()
